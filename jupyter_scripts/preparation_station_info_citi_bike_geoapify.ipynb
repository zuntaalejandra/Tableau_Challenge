# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
stations_data = "data/Catalog_Stations.csv"

# Read School and Student Data File and store into Pandas DataFrames
station_df = pd.read_csv(stations_data)
station_df.head(3)
# Out:
#   Station Id   Latitude  Longitude
# 0    3696.05  40.663062   -73.9539
# 1    4161.01  40.678600   -73.9037
# 2    4243.01  40.681212   -74.0086

# %%
station_data_complete = station_df.copy()

# %%
import requests
from api_keys import geoapify_key

# Iterate through the hotel_df DataFrame
for index, row in station_data_complete.iterrows():

    # get latitude, longitude from the DataFrame

    latitude = station_data_complete.loc[index, "Latitude"]
    longitude = station_data_complete.loc[index, "Longitude"]
        
    # Set base URL
    # base_url = f"https://nominatim.openstreetmap.org/reverse?format=jsonv2&lat={latitude}&lon={longitude}"
    base_url = f"https://api.geoapify.com/v1/geocode/reverse?lat={latitude}&lon={longitude}&format=json&apiKey={geoapify_key}"
    # print(f"url:{base_url}")

    # Make and API request using the params dictionaty
    address = requests.get(base_url)
    
    # Convert the API response to JSON format
    # convert response to json
    address = address.json()
    # print(f"jason: {address}")    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        
        station_data_complete.loc[index, "complete_adress"] = address["results"][0].get("formatted","not found")
        station_data_complete.loc[index, "postcode"] = address["results"][0].get("postcode","not found")
        station_data_complete.loc[index, "county"] = address["results"][0].get("county","Not found")
        station_data_complete.loc[index, "district"] = address["results"][0].get("district","Not found")
        station_data_complete.loc[index, "city"] = address["results"][0].get("city","not found")
        station_data_complete.loc[index, "state"] = address["results"][0].get("state","not found")
        
    except (KeyError, IndexError):
        # print(address)
        # If no info is found
        station_data_complete.loc[index, "postcode"] = "Not found"
        
# Display sample data
station_data_complete
# Out:
#        Station Id   Latitude  Longitude  \
# 0         3696.05  40.663062   -73.9539
# 1         4161.01  40.678600   -73.9037
# 2         4243.01  40.681212   -74.0086
# 3         4476.03  40.690081   -73.9479
# 4         4488.08  40.690238   -73.9920
# ..            ...        ...        ...
# 340         JC116  40.716366   -74.0343
# 341         JCSYS  40.709651   -74.0686
# 342  MTL-ECO5-LAB  40.747166   -74.0890
# 343  Shop Morgan   40.709873   -73.9316
# 344        SYS035  40.728660   -74.0120
#
#                                        complete_adress postcode  \
# 0    404 Rogers Avenue, New York, NY 11225, United ...    11225
# 1    1 Van Sinderen Avenue, New York, NY 11233, Uni...    11233
# 2    Extech Building Materials, 87 Bowne Street, Ne...    11231
# 3    662 Lafayette Avenue, New York, NY 11216, Unit...    11216
# 4    LensCrafters, 121 Court Street, New York, NY 1...    11201
# ..                                                 ...      ...
# 340  Montgomery Street, Jersey City, NJ 07306, Unit...    07306
# 341  198 Forrest Street, Jersey City, NJ 07304, Uni...    07304
# 342  Koppers Dredged Material Recycling Facility, 1...    07032
# 343  154 Morgan Avenue, New York, NY 11237, United ...    11237
# 344  Pier 40, West Houston Street, New York, NY 100...    10014
#
#               county                             district         city  \
# 0       Kings County                             Brooklyn     New York
# 1       Kings County                             Brooklyn     New York
# 2          Not found  Columbia Street Waterfront District     New York
# 3          Not found                            Not found     New York
# 4       Kings County                             Brooklyn     New York
# ..               ...                                  ...          ...
# 340    Hudson County                 Downtown Jersey City  Jersey City
# 341    Hudson County                            Not found  Jersey City
# 342    Hudson County                               Kearny       Kearny
# 343        Not found                            Not found     New York
# 344  New York County                         West Village     New York
#
#           state
# 0      New York
# 1      New York
# 2      New York
# 3      New York
# 4      New York
# ..          ...
# 340  New Jersey
# 341  New Jersey
# 342  New Jersey
# 343    New York
# 344    New York
#
# [345 rows x 9 columns]

# %%
import os
import csv

station_data_complete.to_csv('data\catalog_stations_complete_direction.csv')
